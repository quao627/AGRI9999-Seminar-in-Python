# %% [markdown]
# # Warm-Up

# %% [markdown]
# ## How Python Memory Allocation Works

# %%
a = 10
b = 12
print(id(a) == id(b))
# Out:
# False

# %%
a = 10
b = a
print(id(a) == id(b))
# Out:
# True

# %%
a = 10
b = a
a = 12
print(id(a) == id(b))
# Out:
# False

# %%
a = 10
b = 10
print(id(a) == id(b))
# Out:
# True

# %%
a = 10
id1 = id(a)
a = 12
id2 = id(a)
print(id1 == id2)
# Out:
# False

# %% [markdown]
# # Basic Data Structures

# %% [markdown]
# ## Basic Arithmetics

# %%
a = 1
print(a)
# Out:
# 1

# %%
1 + 1 - 5
# Out:
# -3

# %%
2 * 3
# Out:
# 1.0

# %%
5 / 5
# Out:
# 1.0

# %%
5 // 2
# Out:
# 2

# %%
3 ** 4
# Out:
# 81

# %%
100 % 5
# Out:
# 0

# %%
21 % 5
# Out:
# 1

# %%
(2 + 3)**2 * 2 / 5
# Out:
# 10.0

# %%
a = 1
a += 2
print(a)
a *= 3
print(a)
# Out:
# 3
# 9

# %% [markdown]
# ## String

# %%
# Declare a string and assign it to a variable
a = "Hello World"
print(a)
print(type(a))
# Out:
# Hello World
# <class 'str'>

# %%
# Concatenate two strings
b = "!"
print(a + b)
# Out:
# Hello World!

# %%
# Indexing a string
print("The first character of a: ", a[0])
print("The next two characters of a: ", a[1:3])
print("What about the last character? ", a[-1])
# Out:
# The first character of a:  H
# The next two characters of a:  el
# What about the last character?  d

# %%
# lower case and upper case
print(a.lower())
print(a.upper())
# Out:
# hello world
# HELLO WORLD

# %%
# Split a string
print(a.split())
print(a.split('l'))
# Out:
# ['Hello', 'World']
# ['He', '', 'o Wor', 'd']

# %%
# Join a list of strings into a string
print(''.join(a.split()))
print(' My '.join(a.split()))
# Out:
# HelloWorld
# Hello My World

# %%
# Find the index of the first occurence of a chacter
print(a.index('l'))
print(a.index('l', -3, -1))
print(a.index('He'))

try:
    print(a.index('b'))
except: 
    print('b not found')

print(a.find('b'))
# Out:
# 2
# 9
# 0
# b not found
# -1

# %%
# Replace a specified value by another specified value
print(a.replace('l', 'u'))
print(a.replace('ll', 'l'))
# Out:
# Heuuo Worud
# Helo World

# %%
# Check the starting/ending value
print(a.startswith('He'))
print(a.endswith('!'))
# Out:
# True
# False

# %%
# Trim a string
print("   Hello World   ".strip())
print(a.strip('ld'))
# Out:
# Hello World
# Hello Wor

# %%
# Format a string
text = "{} apples for only {} dollars!"
print(text.format(3, 49))
# Out:
# 3 apples for only 49 dollars!

# %%
# Check if a string is a digit
a = "56"
print(a.isdigit())
a = "h5"
print(a.isdigit())
# Out:
# True
# False

# %%
# Escape
print("'\"Hello\"'")
# Out:
# '"Hello"'

# %%
# Check if a string contains a substring
print('World' in a)
# Out:
# True

# %%
# length of a string
print(len(a))
# Out:
# 11

# %% [markdown]
# ## List

# %%
# Declare a list
a = [1, 'a', True]
print(a)
print(type(a))
# Out:
# [1, 'a', True]
# <class 'list'>

# %%
# Indexing a list
print(a[0], a[2], a[1])
print(a[1:])
print(a[:1])
# Out:
# 1 True a
# ['a', True]
# [1]

# %%
# Concatenate two lists
a + ['b', 'c']
# Out:
# [1, 'a', True, 'b', 'c']

# %%
# Append values to a list
a.append('b')
a.append(['b', 'c'])
print(a)
# Out:
# [1, 'a', True, 'b', ['b', 'c']]

# %%
# Extend a list
a = [1, 'a', True]
a.extend(['b', 'c'])
print(a)
# Out:
# [1, 'a', True, 'b', 'c']

# %%
# Remove a specified item from a list
a.remove('b')
print(a)
# Out:
# [1, 'a', True, 'c']

# %%
# Sort a list
a = [3, 2, 5, 1]
a.sort()
print(a)
# Out:
# [1, 2, 3, 5]

# %%
# Copy a list
c = [1,2]
a = c
a.append(1)
print(c)
c = [1,2]
a = c.copy()
a.append(1)
print(c)
# Out:
# [1, 2, 1]
# [1, 2]

# %% [markdown]
# ## Set

# %%
a = set([1,1,2,2,3])
print(a)
# Out:
# {1, 2, 3}

# %%
# Add an element to a set
a.add(3)
print(a)
a.add(4)
print(a)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}

# %%
# Update a set with another set
a.update([2,3,4,5,6])
print(a)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Union and Intersection
b = set([4,5,6,7,8])
print(a & b)
print(a | b)
# Out:
# {4, 5, 6}
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
try:
    print(b[2])
except:
    print('Set is not subsriptable')
# Out:
# Set is not subsriptable

# %% [markdown]
# ## Tuple

# %%
a = (1, 2, 3)
print(a[1])
# Out:
# 2

# %%
try:
    a[1] = 4
except:
    print("'tuple' object does not support item assignment")
# Out:
# 'tuple' object does not support item assignment

# %% [markdown]
# ## Dictionary

# %%
# Create a dictionary
a = {'Bottled Water': '1 dollar', 'Coke': '2 dollars', 'Apple Juice': '5 dollars'}
print(a)
# Out:
# {'Bottled Water': '1 dollar', 'Coke': '2 dollars', 'Apple Juice': '5 dollars'}

# %%
# Look up a dictionary with a specified key
print(a['Bottled Water'])
print(a.get('Lemonade'))
print(a.get('Lemonade', 0))
# Out:
# 1 dollar
# None
# 0

# %%
# Expand the dictionary
a['Lemonade'] = {'Regular': '4 dollars', 'Strawberry': '6 dollars', 'Vanderbilt Munchie': '10 dollars'}
print(a)
print(a['Lemonade'])
print(a['Lemonade']['Vanderbilt Munchie'])
# Out:
# {'Bottled Water': '1 dollar', 'Coke': '2 dollars', 'Apple Juice': '5 dollars', 'Lemonade': {'Regular': '4 dollars', 'Strawberry': '6 dollars', 'Vanderbilt Munchie': '10 dollars'}}
# {'Regular': '4 dollars', 'Strawberry': '6 dollars', 'Vanderbilt Munchie': '10 dollars'}
# 10 dollars

# %%
menu = dict()
menu['Munchie'] = ["Chicken Sandwich", "Pork Noodle"]
menu['Munchie'] += ['Ice Creame']
print(menu)
# Out:
# {'Munchie': ['Chicken Sandwich', 'Pork Noodle', 'Ice Creame']}

# %%
# Get keys
a.keys()
# Out:
# dict_keys(['Bottled Water', 'Coke', 'Apple Juice'])

# %%
# Get values
a.values()
# Out:
# dict_values(['1 dollar', '2 dollars', '5 dollars'])

# %% [markdown]
# ## Boolean

# %%
print(1 == 1)
print(1 != 1)
# Out:
# True
# False

# %%
a = 1 == 2
print(not a)
# Out:
# True

# %%
'hello'.upper() == 'HELLO'
# Out:
# True

# %%
a = [1,2,3]
b = [1,2,3]
print(a == b)
# Out:
# True

# %%
print(bool('False'))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(''))
# Out:
# False

# %%
(1 + 2 == 3) & (4 - 2 == 2)
# Out:
# True

# %%
(1 + 2 == 3) | (4 - 2 == 1)
# Out:
# True

# %% [markdown]
# ## Conversions between data types

# %%
int('56') + float(4)
# Out:
# 60.0

# %%
"This is not a list: " + str([1,2,3])
# Out:
# 'This is not a list: [1, 2, 3]'

# %%
str(menu)
# Out:
# "{'Munchie': ['Chicken Sandwich', 'Pork Noodle', 'Ice Creame']}"

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# # Control Flow

# %%
# if, elif, and else
user_input = int(input('Please enter an integer: '))

if user_input % 3 == 0:
    print("The input is divisible by 3")
elif user_input % 3 == 1:
    print("The input mod 3 is 1")
else:
    print("The input mod 3 is 2")
# Out:
# Please enter an integer: 5
# The input mod 3 is 2

# %%
# while loop

# Print up to n-th item in fibonacci series
nterms = int(input("How many terms? "))

# first two terms
n1, n2 = 0, 1
count = 0

# check if the number of terms is valid
if nterms <= 0:
    print("Please enter a positive integer")
elif nterms == 1:
    print("Fibonacci sequence upto",nterms,":")
    print(n1)
else:
    print("Fibonacci sequence:")
    while count < nterms:
        # Print the next value
        print(n1)
        nth = n1 + n2
        
        # update values
        n1 = n2
        n2 = nth
        count += 1
# Out:
# How many terms? 5
# Fibonacci sequence:
# 0
# 1
# 1
# 2
# 3

# %%
# for loop, continue, and break

# print the first 20 non-negative integers with prime numebers skipped
# Solution 1
solution_1 = []
for i in range(20):
    prime = True
    if i > 1:
        for j in range(2, int(i/2) + 1, 1): # the last argument is optional
            if i % j == 0:
                prime = False
    
    if (i <= 1) or (not prime):
        solution_1.append(i)

# Solution 2
solution_2 = []
prime_numbers = [2,3,5,7,11,13,17,19]
for i in range(20):
    if i in prime_numbers:
        continue
    solution_2.append(i)

print("Check the solutions: ", solution_1 == solution_2)

# Find the first positive integer with 6 factors
i = 1
while True:
    count = 0
    for j in range(1, i+1):
        if i % j == 0:
            count+=1
    if count == 6:
        print("The smallest positive integer with exactly 6 factors: ", i)
        break
    i += 1
# Out:
# Check the solutions:  True
# The smallest positive integer with exactly 6 factors:  12

# %% [markdown]
# # Write and Read a file

# %%
# Create a file
f = open("demo.txt", "a")
f.write("Now the file has more content!\n")
f.write('And more!')
f.close()

#open and read the file after the appending:
f = open("demo.txt", "r")
print(f.read())
f.close()
# Out:
# Now the file has more content!
# And more!

# %%
f = open("demo.txt", "r")
for line in f.readlines():
    print(line)
# Out:
# Now the file has more content!
#
# And more!

# %%
f = open("demo.txt", "w")
f.write("Oops! I have deleted the content!")
f.close()

f = open("demo.txt", "r")
print(f.read())
# Out:
# Oops! I have deleted the content!

# %%
with open('demo2.txt', 'r') as f:
    content = f.read()
print(content)
print(content.split(' ')[1])
# Out:
# I love python
# love

# %% [markdown]
# # Example: Monte Carlo Simulation

# %%
# Estimate pi

import random
from tqdm import tqdm
  
num_iterations= 10000000
  
circle_points= 0
square_points= 0
  
for i in tqdm(range(num_iterations)):
    # Randomly generate a point
    rand_x= random.uniform(-1, 1)
    rand_y= random.uniform(-1, 1)

    # Calculate distance between the origin and the generated point
    dist= rand_x**2 + rand_y**2

    # Checking if (x, y) lies inside the circle
    if dist<= 1:
        circle_points+= 1

    square_points+= 1

# Make estimation
pi = 4* circle_points/ square_points
print("Final Estimation of Pi=", pi)
# Out:
# 100%|██████████| 10000000/10000000 [00:11<00:00, 854765.35it/s]
# Final Estimation of Pi= 3.1416052

# %%
import matplotlib.pyplot as plt

num_iterations= 10000
x_list = []
y_list = []
color_list = []

for i in tqdm(range(num_iterations)):
    # Randomly generate a point
    rand_x= random.uniform(-1, 1)
    rand_y= random.uniform(-1, 1)
    x_list.append(rand_x)
    y_list.append(rand_y)

    # Calculate distance between the origin and the generated point
    dist= rand_x**2 + rand_y**2

    # Checking if (x, y) lies inside the circle
    if dist<= 1:
        color_list.append('red')
    else:
        color_list.append('blue')

plt.scatter(x=x_list, y=y_list, c=color_list)
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 627748.86it/s]

# %% [markdown]
# # Homework

# %% [markdown]
# **1, Attacker vs Defenser. Who is more advantageous in RISK? (in-class)** <br>
# File: risk.py <br>
# **2, Estimate e using Euler's formula** <br>
# File: euler.py

# %% [markdown]
# # Review

# %% [markdown]
# 1, All data in Python are ... <br>
# 2, What are the differences between list and tuple? <br>
# 3, Explain *continue* and *break* in for/while loop? <br>
# 4, When do we user
# 4, What is the advantage of using "with" to create, write, or open a file? <br>
# 5, What is monte carlo simulation? <br>
